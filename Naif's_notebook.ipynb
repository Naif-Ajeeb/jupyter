# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![image.png](attachment:ed3880dd-5c97-4a1f-9549-7365771fa08d.jpg)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ![3-intro.png.jpg](attachment:aab9024d-89c8-498c-b480-637980e090cc.jpg)

# %% [markdown]
# **Objectives:**
#
# - list the libraries used in data science.
# - list the popular languages in data science.
# - revise how to do simple markdown techniques.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1- python
#
# 2- R language
#
# 3- julia

# %% [markdown]
# ![4-dslanguages.png.jpg](attachment:7119f250-00a5-4aa9-850e-6be73f58635b.jpg)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# 1- ggplot
#
# 2- pandas
#
# 3- matplotlib

# %% [markdown]
# ![5-dslibraries.png.jpg](attachment:6bf714d2-e202-4ebc-a098-bb1378dc2462.jpg)

# %% [markdown]
# |data science tools:|
# |-----|
# |vs code|
# |RStudio|
# |jupyter lab|

# %% [markdown]
# ![dstools.png.jpg](attachment:899b8e13-59b6-4254-a210-7f03850c8fae.jpg)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %% [markdown]
# ![introarithmetic.png.jpg](attachment:1416a83a-7a0e-42b2-819b-d04ff297d819.jpg)

# %%
# This will convert 200 minutes to hours by diving by 60

def tohours(minutes):
    hours = minutes/60
    return hours


tohours(200)
# Out:
# 3.3333333333333335

# %% [markdown]
# ![tohours.png.jpg](attachment:a38becad-e895-4f8e-a402-bfd26e012374.jpg)

# %% [markdown]
# ## author:
#
# Naif Saleh Ajeeb. :)
